# %%
import pandas as pd

# %%
df=pd.read_csv("movies.csv")
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          NaN             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# 3      USD  English
# 4      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
array=df[["title", "industry", "studio","language", ]]

# %%
array.columns
# Out:
# Index(['title', 'industry', 'studio'], dtype='object')

# %%
array["title"]
# Out:
# 0                                 Pather Panchali
# 1     Doctor Strange in the Multiverse of Madness
# 2                           Thor: The Dark World
# 3                                 Thor: Ragnarok
# 4                         Thor: Love and Thunder
# 5                        The Shawshank Redemption
# 6                                    Interstellar
# 7                        The Pursuit of Happyness
# 8                                       Gladiator
# 9                                         Titanic
# 10                          It's a Wonderful Life
# 11                                         Avatar
# 12                                  The Godfather
# 13                                The Dark Knight
# 14                               Schindler's List
# 15                                  Jurassic Park
# 16                                       Parasite
# 17                              Avengers: Endgame
# 18                         Avengers: Infinity War
# 19             Captain America: The First Avenger
# 20            Captain America: The Winter Soldier
# 21                    Dilwale Dulhania Le Jayenge
# 22                                       3 Idiots
# 23                       Kabhi Khushi Kabhie Gham
# 24                               Bajirao Mastani
# 25                               Taare Zameen Par
# 26                            Munna Bhai M.B.B.S.
# 27                                             PK
# 28                                          Sanju
# 29                              The Kashmir Files
# 30                              Bajrangi Bhaijaan
# 31                                         Race 3
# 32                                      Shershaah
# 33                               K.G.F: Chapter 2
# 34                      Pushpa: The Rise - Part 1
# 35                                            RRR
# 36                       Baahubali: The Beginning
# Name: title, dtype: object

# %%
array["language"].unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
array.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df[(df.release_year >= 2013) & (df.release_year <= 2022)]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 6                                  Interstellar  Hollywood          2014
# 16                                     Parasite  Hollywood          2019
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 20          Captain America: The Winter Soldier  Hollywood          2014
# 24                             Bajirao Mastani   Bollywood          2015
# 27                                           PK  Bollywood          2014
# 28                                        Sanju  Bollywood          2018
# 29                            The Kashmir Files  Bollywood          2022
# 30                            Bajrangi Bhaijaan  Bollywood          2015
# 31                                       Race 3        NaN          2018
# 32                                    Shershaah  Bollywood          2021
# 33                             K.G.F: Chapter 2  Bollywood          2022
# 34                    Pushpa: The Rise - Part 1  Bollywood          2021
# 35                                          RRR  Bollywood          2022
# 36                     Baahubali: The Beginning  Bollywood          2015
#
#     imdb_rating                 studio  budget  revenue      unit currency  \
# 1           NaN         Marvel Studios   200.0    954.8  Millions      USD
# 2           6.8         Marvel Studios   165.0    644.8  Millions      USD
# 3           7.9         Marvel Studios   180.0    854.0  Millions      USD
# 4           6.8         Marvel Studios   250.0    670.0  Millions      USD
# 6           8.6  Warner Bros. Pictures     NaN    701.8  Millions      USD
# 16          8.5                    NaN    15.5    263.1  Millions      USD
# 17          8.4         Marvel Studios     NaN   2798.0  Millions      USD
# 18          8.4         Marvel Studios   400.0   2048.0  Millions      USD
# 20          7.8         Marvel Studios   177.0    714.4  Millions      USD
# 24          7.2                    NaN     1.4      3.5  Billions      INR
# 27          8.1     Vinod Chopra Films   850.0   8540.0  Millions      INR
# 28          NaN     Vinod Chopra Films     NaN      5.9  Billions      INR
# 29          8.3            Zee Studios   250.0   3409.0  Millions      INR
# 30          8.1      Salman Khan Films   900.0  11690.0  Millions      INR
# 31          1.9      Salman Khan Films     1.8      3.1  Billions      INR
# 32          8.4     Dharma Productions   500.0    950.0  Millions      INR
# 33          8.4          Hombale Films     NaN     12.5  Billions      INR
# 34          7.6    Mythri Movie Makers     NaN      3.6  Billions      INR
# 35          8.0      DVV Entertainment     5.5     12.0  Billions      INR
# 36          8.0       Arka Media Works     1.8      6.5  Billions      INR
#
#    language
# 1   English
# 2   English
# 3   English
# 4   English
# 6   English
# 16  English
# 17  English
# 18  English
# 20  English
# 24    Hindi
# 27    Hindi
# 28    Hindi
# 29    Hindi
# 30    Hindi
# 31    Hindi
# 32    Hindi
# 33  Kannada
# 34   Telugu
# 35   Telugu
# 36   Telugu

# %%
df[(df.imdb_rating==df.imdb_rating.max()) | (df.imdb_rating==df.imdb_rating.min()) ]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3        NaN          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
# iddentifying missing value

df.isnull().any()
# Out:
# title           False
# industry         True
# release_year    False
# imdb_rating      True
# studio           True
# budget           True
# revenue         False
# unit            False
# currency        False
# language        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# title           0
# industry        2
# release_year    0
# imdb_rating     2
# studio          3
# budget          6
# revenue         0
# unit            0
# currency        0
# language        0
# dtype: int64

# %%
df.
